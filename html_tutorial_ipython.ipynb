# %% [markdown]
# <a href="https://colab.research.google.com/github/KJ19741/Manning-Live-Project/blob/main/html_tutorial_ipython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HTML Tutorial for Beginners

# %% [markdown]
# ## Introduction
# This tutorial will introduce you to the basics of HTML, the standard markup language for creating web pages.

# %% [markdown]
# ## What is HTML?
# HTML stands for Hyper Text Markup Language. It is the standard markup language for creating web pages and web applications.

# %% [markdown]
# ## Basic Structure of an HTML Page

# %%
from IPython.display import HTML
HTML('''
<!DOCTYPE html>
<html>
<head>
    <title>Page Title</title>
</head>
<body>
    <h1>My First Heading</h1>
    <p>My first paragraph.</p>
</body>
</html>
''')

# %% [markdown]
# ## Headings
# HTML headings are defined with the `<h1>` to `<h6>` tags.

# %%
from IPython.display import HTML
HTML('''
<h1>This is heading 1</h1>
<h2>This is heading 2</h2>
<h3>This is heading 3</h3>
''')

# %% [markdown]
# ## Paragraphs
# HTML paragraphs are defined with the `<p>` tag.

# %%
from IPython.display import HTML
HTML('''
<p>This is a paragraph.</p>
<p>This is another paragraph.</p>
''')

# %% [markdown]
# ## Links
# HTML links are defined with the `<a>` tag.

# %%
from IPython.display import HTML
HTML('''
<a href='https://www.example.com'>This is a link</a>
''')

# %% [markdown]
# ## Images
# HTML images are defined with the `<img>` tag.

# %%
from IPython.display import HTML
HTML('''
<img src='url' alt='Alternate text' width='100' height='100'>
''')

# %% [markdown]
# ## Lists
# HTML supports ordered and unordered lists.

# %%
from IPython.display import HTML
HTML('''
<ul>
    <li>Coffee</li>
    <li>Tea</li>
    <li>Milk</li>
</ul>
<ol>
    <li>First item</li>
    <li>Second item</li>
</ol>
''')

# %% [markdown]
# ## Putting It All Together
# Let's create a simple webpage using what we've learned.

# %%
from IPython.display import HTML
HTML('''
<!DOCTYPE html>
<html>
<head>
    <title>My Web Page</title>
</head>
<body>
    <h1>Welcome to My Web Page</h1>
    <p>This is a paragraph on my web page.</p>
    <a href='https://www.example.com'>Visit Example</a>
    <h2>My Favorite Foods</h2>
    <ul>
        <li>Pizza</li>
        <li>Sushi</li>
        <li>Chocolate</li>
    </ul>
</body>
</html>
''')

# %%
from google.colab import files
uploaded = files.upload()  # choose index.html, styles.css, and any assets
# Out:
#      <input type="file" id="files-4c05bd41-4822-451f-a58e-0f2225126607" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c05bd41-4822-451f-a58e-0f2225126607">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os, portpicker, textwrap
from google.colab import output
from IPython.display import IFrame

# Serve /content on an available port
port = portpicker.pick_unused_port()
# Quiet background server
get_ipython().system_raw(f"python3 -m http.server {port} --directory /content >/dev/null 2>&1 &")

# Create a proxied URL that works inside Colab
public_url = output.eval_js(f"google.colab.kernel.proxyPort({port})")
IFrame(public_url + "/index.html", width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="https://41067-m-s-25beduqwqpoe5-c.us-east1-1.prod.colab.dev/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
